# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\e1077783\Downloads\NIFTY50all01-01-2008-TO-30-12-2008.csv")

# %%
df.head()
# Out:
#           Date    P/E   P/B  Div Yield
# 0  01-Jan-2008  27.64  6.40       0.84
# 1  02-Jan-2008  27.80  6.43       0.83
# 2  03-Jan-2008  27.80  6.43       0.83
# 3  04-Jan-2008  28.23  6.53       0.82
# 4  07-Jan-2008  28.25  6.54       0.82

# %%
df = df.set_index('Date')
df.head()
# Out:
#                P/E   P/B  Div Yield
# Date
# 01-Jan-2008  27.64  6.40       0.84
# 02-Jan-2008  27.80  6.43       0.83
# 03-Jan-2008  27.80  6.43       0.83
# 04-Jan-2008  28.23  6.53       0.82
# 07-Jan-2008  28.25  6.54       0.82

# %%
pe = df[["P/E"]]

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %%
pe.plot(kind='line')

# %%
import os
import pandas as pd
p = r"C:\Users\e1077783\Downloads"

fs = [name for name in os.listdir(p) if os.path.isfile(os.path.join(p, name)) and name.startswith('NIFTY')]
dfs = []
for each in fs:
    dfs.append(pd.read_csv(os.path.join(p, each)))
print(dfs)
# Out:
# [            Date    P/E   P/B  Div Yield
# 0    01-Jan-2008  27.64  6.40       0.84
# 1    02-Jan-2008  27.80  6.43       0.83
# 2    03-Jan-2008  27.80  6.43       0.83
# 3    04-Jan-2008  28.23  6.53       0.82
# 4    07-Jan-2008  28.25  6.54       0.82
# 5    08-Jan-2008  28.29  6.55       0.82
# 6    09-Jan-2008  28.22  6.53       0.82
# 7    10-Jan-2008  27.70  6.41       0.83
# 8    11-Jan-2008  27.86  6.46       0.83
# 9    14-Jan-2008  27.89  6.47       0.83
# 10   15-Jan-2008  27.30  6.33       0.85
# 11   16-Jan-2008  26.67  6.18       0.87
# 12   17-Jan-2008  25.47  6.16       0.87
# 13   18-Jan-2008  24.49  5.94       0.90
# 14   21-Jan-2008  22.33  5.43       0.99
# 15   22-Jan-2008  20.96  5.10       1.05
# 16   23-Jan-2008  22.26  5.42       0.99
# 17   24-Jan-2008  21.52  5.24       1.02
# 18   25-Jan-2008  22.88  5.61       0.95
# 19   28-Jan-2008  22.60  5.52       0.97
# 20   29-Jan-2008  22.55  5.53       0.97
# 21   30-Jan-2008  22.02  5.41       0.99
# 22   31-Jan-2008  21.97  5.38       0.99
# 23   01-Feb-2008  22.68  5.57       0.96
# 24   04-Feb-2008  23.31  5.72       0.94
# 25   05-Feb-2008  23.40  5.74       0.93
# 26   06-Feb-2008  22.71  5.58       0.96
# 27   07-Feb-2008  21.90  5.38       1.00
# 28   08-Feb-2008  21.85  5.36       1.00
# 29   11-Feb-2008  20.72  5.09       1.05
# ..           ...    ...   ...        ...
# 215  14-Nov-2008  12.31  2.36       2.01
# 216  17-Nov-2008  12.26  2.35       2.01
# 217  18-Nov-2008  11.75  2.25       2.11
# 218  19-Nov-2008  11.54  2.21       2.14
# 219  20-Nov-2008  11.18  2.15       2.21
# 220  21-Nov-2008  11.80  2.26       2.10
# 221  24-Nov-2008  11.86  2.28       2.09
# 222  25-Nov-2008  11.63  2.23       2.13
# 223  26-Nov-2008  12.06  2.31       2.05
# 65  04-Apr-2019  28.95  3.70       1.14
# 66  05-Apr-2019  29.12  3.72       1.13
# 67  08-Apr-2019  28.96  3.70       1.14
# 68  09-Apr-2019  29.13  3.72       1.13
# 69  10-Apr-2019  28.91  3.70       1.14
# 70  11-Apr-2019  28.94  3.70       1.14
# 71  12-Apr-2019  29.06  3.72       1.13
# 72  15-Apr-2019  29.18  3.73       1.13
# 73  16-Apr-2019  29.42  3.76       1.12
# 74  18-Apr-2019  29.33  3.75       1.12
#
# [75 rows x 4 columns]]

# %%
len(dfs)
# Out:
# 12

# %%
df = pd.concat(dfs, ignore_index=False)
df.shape
# Out:
# (2789, 4)

# %%
df = df.set_index('Date')
df.head()
# Out:
#                P/E   P/B  Div Yield
# Date
# 01-Jan-2008  27.64  6.40       0.84
# 02-Jan-2008  27.80  6.43       0.83
# 03-Jan-2008  27.80  6.43       0.83
# 04-Jan-2008  28.23  6.53       0.82
# 07-Jan-2008  28.25  6.54       0.82

# %%
pe = df[["P/E"]]
pe.head()
# Out:
#                P/E
# Date
# 01-Jan-2008  27.64
# 02-Jan-2008  27.80
# 03-Jan-2008  27.80
# 04-Jan-2008  28.23
# 07-Jan-2008  28.25

# %%
pe.plot(kind='line')

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.0.2

# %%
pepb = df[['P/E', 'P/B']]
pepb.plot(kind='line', figsize= (30, 10))
plt.xticks(range(2008, 2019, 1))
plt.show()

# %%
df.head()
# Out:
#                P/E   P/B  Div Yield
# Date
# 01-Jan-2008  27.64  6.40       0.84
# 02-Jan-2008  27.80  6.43       0.83
# 03-Jan-2008  27.80  6.43       0.83
# 04-Jan-2008  28.23  6.53       0.82
# 07-Jan-2008  28.25  6.54       0.82

# %%
df.index
#df['Year'] = list(map(lambda x : x.month, df.index ))
# Out:
# Index(['01-Jan-2008', '02-Jan-2008', '03-Jan-2008', '04-Jan-2008',
#        '07-Jan-2008', '08-Jan-2008', '09-Jan-2008', '10-Jan-2008',
#        '11-Jan-2008', '14-Jan-2008',
#        ...
#        '04-Apr-2019', '05-Apr-2019', '08-Apr-2019', '09-Apr-2019',
#        '10-Apr-2019', '11-Apr-2019', '12-Apr-2019', '15-Apr-2019',
#        '16-Apr-2019', '18-Apr-2019'],
#       dtype='object', name='Date', length=2789)

# %%
import time
t = time.strptime('01-Jan-2008', "%d-%b-%Y")

# %%
t.tm_mday
# Out:
# 1

# %%
df['Year'] = list(map(lambda x : time.strptime(x, "%d-%b-%Y").tm_year, df.index ))

# %%
df['Month'] = list(map(lambda x: time.strptime(x, "%d-%b-%Y").tm_mon, df.index))

# %%
df[["P/E", "P/B", "Month"]].groupby("Month").mean()
# Out:
#              P/E       P/B
# Month
# 1      21.422840  3.471012
# 2      20.814832  3.392605
# 3      20.963074  3.392336
# 4      21.481892  3.555000
# 5      21.012000  3.554809
# 6      21.146638  3.528894
# 7      21.322934  3.486322
# 8      21.405852  3.396769
# 9      21.591071  3.368839
# 10     21.286409  3.269455
# 11     21.008904  3.227900
# 12     20.893616  3.209018

# %%
df[["P/E", "P/B", "Year"]].groupby("Year").mean()
# Out:
#             P/E       P/B
# Year
# 2008  18.693265  4.246082
# 2009  18.693264  3.224215
# 2010  22.882908  3.694502
# 2011  19.797045  3.290486
# 2012  18.054400  2.998040
# 2013  17.764980  3.003454
# 2014  19.896667  3.324115
# 2015  22.438502  3.446235
# 2016  21.940324  3.205466
# 2017  24.728266  3.467218
# 2018  26.412939  3.560286
# 2019  27.187333  3.485600

# %%
t = time.strptime('01-Jan-2019', "%d-%b-%Y")

# %%
t
# Out:
# time.struct_time(tm_year=2019, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=1, tm_isdst=-1)

# %%
from dateutil.relativedelta import *

# %%
import datetime

# %%
d = datetime.date(year = t.tm_year, month = t.tm_mon, day = t.tm_mday)

# %%
d+relativedelta(days = +1)
# Out:
# datetime.date(2019, 1, 2)

# %%
d + relativedelta(months = +1)
# Out:
# datetime.date(2019, 2, 1)

# %%
d + relativedelta(months = +1, days=+29)
# Out:
# datetime.date(2019, 3, 2)

# %%
import calendar
#for finding out last thrusday
print(d + relativedelta(days = 9, weekday = TH(-1)))
print(d + relativedelta(months = 1, weekday = TH(-1)))
# Out:
# 2019-01-10
# 2019-01-31

# %%
last_thursdays = []
for year in range(2008, 2020):
    for month in range(1, 13):
        d = datetime.date(year= year, month = month, day =1)
        last_thursdays.append(d+relativedelta(days=1, weekday= TH(-1)))
print(len(last_thursdays))
# Out:
# 144

# %%
data_indices = []
for th in last_thursdays:
    data_indices.append(th.strftime("%d-%b-%Y"))

# %%
data_indices
# Out:
# ['27-Dec-2007',
#  '31-Jan-2008',
#  '28-Feb-2008',
#  '27-Mar-2008',
#  '01-May-2008',
#  '29-May-2008',
#  '26-Jun-2008',
#  '31-Jul-2008',
#  '28-Aug-2008',
#  '02-Oct-2008',
#  '30-Oct-2008',
#  '27-Nov-2008',
#  '01-Jan-2009',
#  '29-Jan-2009',
#  '26-Feb-2009',
#  '02-Apr-2009',
#  '30-Apr-2009',
#  '28-May-2009',
#  '02-Jul-2009',
#  '30-Jul-2009',
#  '27-Aug-2009',
#  '01-Oct-2009',
#  '29-Oct-2009',
#  '26-Nov-2009',
#  '31-Dec-2009',
#  '28-Jan-2010',
#  '25-Feb-2010',
#  '01-Apr-2010',
#  '29-Apr-2010',
#  '27-May-2010',
#  '01-Jul-2010',
#  '29-Jul-2010',
#  '02-Sep-2010',
#  '30-Sep-2010',
#  '28-Oct-2010',
#  '02-Dec-2010',
#  '30-Dec-2010',
#  '27-Jan-2011',
#  '24-Feb-2011',
#  '31-Mar-2011',
#  '28-Apr-2011',
#  '02-Jun-2011',
#  '30-Jun-2011',
#  '28-Jul-2011',
#  '01-Sep-2011',
#  '29-Sep-2011',
#  '27-Oct-2011',
#  '01-Dec-2011',
#  '29-Dec-2011',
#  '02-Feb-2012',
#  '01-Mar-2012',
#  '29-Mar-2012',
#  '26-Apr-2012',
#  '31-May-2012',
#  '28-Jun-2012',
#  '02-Aug-2012',
#  '30-Aug-2012',
#  '27-Sep-2012',
#  '01-Nov-2012',
#  '29-Nov-2012',
#  '27-Dec-2012',
#  '31-Jan-2013',
#  '28-Feb-2013',
#  '28-Mar-2013',
#  '02-May-2013',
#  '30-May-2013',
#  '27-Jun-2013',
#  '01-Aug-2013',
#  '29-Aug-2013',
#  '26-Sep-2013',
#  '31-Oct-2013',
#  '28-Nov-2013',
#  '02-Jan-2014',
#  '30-Jan-2014',
#  '27-Feb-2014',
#  '27-Mar-2014',
#  '01-May-2014',
#  '29-May-2014',
#  '26-Jun-2014',
#  '31-Jul-2014',
#  '28-Aug-2014',
#  '02-Oct-2014',
#  '30-Oct-2014',
#  '27-Nov-2014',
#  '01-Jan-2015',
#  '29-Jan-2015',
#  '26-Feb-2015',
#  '02-Apr-2015',
#  '30-Apr-2015',
#  '28-May-2015',
#  '02-Jul-2015',
#  '30-Jul-2015',
#  '27-Aug-2015',
#  '01-Oct-2015',
#  '29-Oct-2015',
#  '26-Nov-2015',
#  '31-Dec-2015',
#  '28-Jan-2016',
#  '25-Feb-2016',
#  '31-Mar-2016',
#  '28-Apr-2016',
#  '02-Jun-2016',
#  '30-Jun-2016',
#  '28-Jul-2016',
#  '01-Sep-2016',
#  '29-Sep-2016',
#  '27-Oct-2016',
#  '01-Dec-2016',
#  '29-Dec-2016',
#  '02-Feb-2017',
#  '02-Mar-2017',
#  '30-Mar-2017',
#  '27-Apr-2017',
#  '01-Jun-2017',
#  '29-Jun-2017',
#  '27-Jul-2017',
#  '31-Aug-2017',
#  '28-Sep-2017',
#  '02-Nov-2017',
#  '30-Nov-2017',
#  '28-Dec-2017',
#  '01-Feb-2018',
#  '01-Mar-2018',
#  '29-Mar-2018',
#  '26-Apr-2018',
#  '31-May-2018',
#  '28-Jun-2018',
#  '02-Aug-2018',
#  '30-Aug-2018',
#  '27-Sep-2018',
#  '01-Nov-2018',
#  '29-Nov-2018',
#  '27-Dec-2018',
#  '31-Jan-2019',
#  '28-Feb-2019',
#  '28-Mar-2019',
#  '02-May-2019',
#  '30-May-2019',
#  '27-Jun-2019',
#  '01-Aug-2019',
#  '29-Aug-2019',
#  '26-Sep-2019',
#  '31-Oct-2019',
#  '28-Nov-2019']

# %%
df.loc[data_indices]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                P/E   P/B  Div Yield    Year  Month
# Date
# 31-Jan-2008  21.97  5.38       0.99  2008.0    1.0
# 28-Feb-2008  22.53  5.54       0.97  2008.0    2.0
# 27-Mar-2008  21.05  5.19       1.04  2008.0    3.0
# 01-May-2008    NaN   NaN        NaN     NaN    NaN
# 29-May-2008  20.59  4.97       1.10  2008.0    5.0
# 26-Jun-2008  18.45  4.27       1.26  2008.0    6.0
# 31-Jul-2008  18.22  3.99       1.28  2008.0    7.0
# 28-Aug-2008  17.81  3.70       1.33  2008.0    8.0
# 25-Sep-2008  17.66  3.42       1.38  2008.0    9.0
# 30-Oct-2008    NaN   NaN        NaN     NaN    NaN
# 27-Nov-2008    NaN   NaN        NaN     NaN    NaN
# 01-Jan-2009  13.30  2.50       1.86  2009.0    1.0
# 29-Jan-2009  13.17  2.35       1.98  2009.0    1.0
# 26-Feb-2009  13.22  2.31       2.01  2009.0    2.0
# 26-Mar-2009  14.64  2.56       1.82  2009.0    3.0
# 30-Apr-2009    NaN   NaN        NaN     NaN    NaN
# 28-May-2009  20.32  3.54       1.27  2009.0    5.0
# 25-Jun-2009  19.07  3.46       1.30  2009.0    6.0
# 30-Jul-2009  20.31  3.68       1.12  2009.0    7.0
# 27-Aug-2009  21.01  3.67       1.09  2009.0    8.0
# 01-Oct-2009  22.89  3.76       1.00  2009.0   10.0
# 29-Oct-2009  21.00  3.56       1.05  2009.0   10.0
# 26-Nov-2009  22.25  3.54       0.99  2009.0   11.0
# 31-Dec-2009    NaN   NaN        NaN     NaN    NaN
# 28-Jan-2010  21.09  3.42       1.01  2010.0    1.0
# 25-Feb-2010  20.79  3.42       1.02  2010.0    2.0
# 01-Apr-2010  22.52  3.73       0.93  2010.0    4.0
# 29-Apr-2010  22.22  3.74       0.93  2010.0    4.0
# 27-May-2010  20.88  3.56       0.98  2010.0    5.0
# 01-Jul-2010  21.99  3.74       0.94  2010.0    7.0
# ...            ...   ...        ...     ...    ...
# 27-Jul-2017  25.56  3.57       1.00  2017.0    7.0
# 31-Aug-2017  25.62  3.49       0.94  2017.0    8.0
# 28-Sep-2017  25.44  3.40       0.97  2017.0    9.0
# 26-Oct-2017  26.73  3.49       1.10  2017.0   10.0
# 30-Nov-2017  26.16  3.45       1.11  2017.0   11.0
# 28-Dec-2017  26.82  3.53       1.08  2017.0   12.0
# 01-Feb-2018  27.48  3.72       1.03  2018.0    2.0
# 01-Mar-2018  25.59  3.53       1.19  2018.0    3.0
# 29-Mar-2018    NaN   NaN        NaN     NaN    NaN
# 26-Apr-2018  26.36  3.65       1.21  2018.0    4.0
# 31-May-2018  27.19  3.69       1.23  2018.0    5.0
# 28-Jun-2018  25.57  3.64       1.25  2018.0    6.0
# 26-Jul-2018  27.75  3.64       1.20  2018.0    7.0
# 30-Aug-2018  28.51  3.76       1.15  2018.0    8.0
# 27-Sep-2018  26.69  3.47       1.23  2018.0    9.0
# 01-Nov-2018  24.98  3.29       1.27  2018.0   11.0
# 29-Nov-2018  26.27  3.43       1.22  2018.0   11.0
# 27-Dec-2018  26.08  3.41       1.23  2018.0   12.0
# 31-Jan-2019  26.26  3.37       1.25  2019.0    1.0
# 28-Feb-2019  26.32  3.41       1.25  2019.0    2.0
# 28-Mar-2019  28.36  3.65       1.17  2019.0    3.0
# 25-Apr-2019    NaN   NaN        NaN     NaN    NaN
# 30-May-2019    NaN   NaN        NaN     NaN    NaN
# 27-Jun-2019    NaN   NaN        NaN     NaN    NaN
# 01-Aug-2019    NaN   NaN        NaN     NaN    NaN
# 29-Aug-2019    NaN   NaN        NaN     NaN    NaN
# 26-Sep-2019    NaN   NaN        NaN     NaN    NaN
# 31-Oct-2019    NaN   NaN        NaN     NaN    NaN
# 28-Nov-2019    NaN   NaN        NaN     NaN    NaN
# 26-Dec-2019    NaN   NaN        NaN     NaN    NaN
#
# [144 rows x 5 columns]

# %%
def get_last_thrusdays_of_every_month(start_year, end_year):
    last_thursdays = []
    for year in range(start_year, end_year+1):
        for month in range(1, 13):
            d = datetime.date(year= year, month = month, day =1)
            thurs = d+relativedelta(days=31, weekday= TH(-1))
            #this condition is necessary because 
            if thurs.month != month:
                thurs = d+relativedelta(days=31, weekday= TH(-2))
            last_thursdays.append(thurs)
    print(len(last_thursdays))
    return last_thursdays

# %%
last_thursdays = get_last_thrusdays_of_every_month(2008, 2019)
# Out:
# 144

# %%
data_indices = []
for th in last_thursdays:
    data_indices.append(th.strftime("%d-%b-%Y"))

# %%
df_option_expiry = df.loc[data_indices, ["P/E"]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
df_option_expiry.plot(kind= 'bar', figsize=(20, 10))

# %%
df_option_expiry.dropna()
df_option_expiry.plot(kind='area', figsize=(20,10))

# %%
#ax = df[["P/E"]].plot(kind='line', figsize=(20,10))
#df_option_expiry.plot(ax= ax, kind='line', marker='o')
df_option_expiry.dropna(inplace=True)
#df_option_expiry.plot(kind='line')
df[["P/E"]].plot(kind='line', figsize=(20,10))
plt.xticks(range(2008, 2020))
plt.xlabel('Years')
plt.show()

# %%
import numpy as np
df[["P/E"]].plot(kind='line', figsize=(20,10))
plt.xlabel('Dates')
plt.show()

# %%
x = range(1,100, 5)
y = range(1,60, 3)
plt.plot(x, y, 'b')
plt.xticks(range(1,100, 10))
plt.show()

# %%
dic = {'col1': x, 'col2': y}
df1 = pd.DataFrame.from_dict(data=dic)

# %%
df1 = df1.set_index('col2')

# %%
df1.plot(kind='line', xticks=range(0, 60, 5))

# %%
pe_monthly = df[["P/E", "Month"]].groupby('Month').mean()

# %%
pe_monthly.plot(kind='bar', figsize=(20,10))

# %%
pe_grp_monthly = df[["P/E", "Month"]].groupby('Month')

# %%
dir(pe_grp_monthly)
# Out:
# ['Month',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_block_agg_axis',
#  '_bool_agg',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_decide_output_index',
#  '_def_str',
#  '_define_paths',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_fill',
#  '_get_cythonized_result',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_gotitem',
#  '_group_selection',
#  '_insert_inaxis_grouper_inplace',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cython_func',
#  '_iterate_column_groupbys',
#  '_iterate_slices',
#  '_make_wrapper',
#  '_obj_with_exclusions',
#  '_post_process_cython_aggregate',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_reindex_output',
#  '_reset_cache',
#  '_reset_group_selection',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_group_selection',
#  '_set_result_index_ordered',
#  '_shallow_copy',
#  '_transform_fast',
#  '_transform_general',
#  '_transform_item_by_item',
#  '_transform_should_cast',
#  '_try_aggregate_string_function',
#  '_try_cast',
#  '_wrap_agged_blocks',
#  '_wrap_aggregated_output',
#  '_wrap_applied_output',
#  '_wrap_generic_output',
#  '_wrap_transformed_output',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'backfill',
#  'bfill',
#  'boxplot',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'dtypes',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'get_group',
#  'groups',
#  'head',
#  'hist',
#  'idxmax',
#  'idxmin',
#  'indices',
#  'last',
#  'mad',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'ndim',
#  'ngroup',
#  'ngroups',
#  'nth',
#  'nunique',
#  'ohlc',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'rank',
#  'resample',
#  'rolling',
#  'sem',
#  'shift',
#  'size',
#  'skew',
#  'std',
#  'sum',
#  'tail',
#  'take',
#  'transform',
#  'tshift',
#  'var']

# %%
pe_grp_monthly.std()
# Out:
#             P/E
# Month
# 1      4.028706
# 2      3.510777
# 3      3.582511
# 4      3.372504
# 5      2.742374
# 6      2.787887
# 7      3.131431
# 8      3.511553
# 9      3.400429
# 10     3.735291
# 11     3.873666
# 12     3.801147

# %%
pe_grp_monthly.boxplot(figsize=(20,10))
# Out:
# 1          AxesSubplot(0.1,0.736957;0.235294x0.163043)
# 2     AxesSubplot(0.382353,0.736957;0.235294x0.163043)
# 3     AxesSubplot(0.664706,0.736957;0.235294x0.163043)
# 4          AxesSubplot(0.1,0.541304;0.235294x0.163043)
# 5     AxesSubplot(0.382353,0.541304;0.235294x0.163043)
# 6     AxesSubplot(0.664706,0.541304;0.235294x0.163043)
# 7          AxesSubplot(0.1,0.345652;0.235294x0.163043)
# 8     AxesSubplot(0.382353,0.345652;0.235294x0.163043)
# 9     AxesSubplot(0.664706,0.345652;0.235294x0.163043)
# 10             AxesSubplot(0.1,0.15;0.235294x0.163043)
# 11        AxesSubplot(0.382353,0.15;0.235294x0.163043)
# 12        AxesSubplot(0.664706,0.15;0.235294x0.163043)
# dtype: object

# %%
df.boxplot(column='P/E', by='Month', figsize=(20,10))
plt.ylabel('P/E')
plt.suptitle('') #this removes the autogenerated title
plt.title('Nifty 50 P/E grouped monthly from 2008 to 2019')
#shows that May and June are usually less volatile months
# Out:
# Text(0.5, 1.0, 'Nifty 50 P/E grouped monthly from 2008 to 2019')

# %%
df.boxplot(column ='P/E', by='Year', figsize=(20,10))
plt.title("Nifty 50 P/E yearly ")
plt.ylabel('P/E')
plt.suptitle('')

#Shows that there was too much volatility in 2008, 2009 but later it was reduced.
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# Adding more data from previous years, so that we cover more election years

# %%
def load_nifty_data(path):
    fs = [name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name)) and name.startswith('NIFTY')]
    dfs = []
    for each in fs:
        dfs.append(pd.read_csv(os.path.join(p, each)))
    df = pd.concat(dfs, ignore_index = False)
    return df

p = r"C:\Users\e1077783\Downloads"
df_50 = load_data(p, "NIFTY50")
df_50.shape
# Out:
# (4044, 4)

# %%
df_50['Month'] = list(map(lambda x: time.strptime(x, "%d-%b-%Y").tm_mon, df_50['Date']))

# %%
df_50.tail()
# Out:
#            Date    P/E   P/B  Div Yield  Month
# 70  11-Apr-2019  28.94  3.70       1.14      4
# 71  12-Apr-2019  29.06  3.72       1.13      4
# 72  15-Apr-2019  29.18  3.73       1.13      4
# 73  16-Apr-2019  29.42  3.76       1.12      4
# 74  18-Apr-2019  29.33  3.75       1.12      4

# %%
df_50['Year'] = list(map(lambda x: time.strptime(x, "%d-%b-%Y").tm_year, df_50['Date']))

# %%
df_50.tail()
# Out:
#            Date    P/E   P/B  Div Yield  Month  Year
# 70  11-Apr-2019  28.94  3.70       1.14      4  2019
# 71  12-Apr-2019  29.06  3.72       1.13      4  2019
# 72  15-Apr-2019  29.18  3.73       1.13      4  2019
# 73  16-Apr-2019  29.42  3.76       1.12      4  2019
# 74  18-Apr-2019  29.33  3.75       1.12      4  2019

# %% [markdown]
# # Adding data from 2003 shows that there is Nifty 50 P/E variabality is similar across months

# %%
df_50.boxplot(column='P/E', by='Month', figsize=(20, 10))
plt.suptitle('')
plt.title("Nifty 50 P/E monthly from 2003 to 2019")
# Out:
# Text(0.5, 1.0, 'Nifty 50 P/E monthly from 2003 to 2019')

# %% [markdown]
# # Adding data from 2003 shows the most volatile years were 2004, 2008 and 2009

# %%
df_50.boxplot(column='P/E', by='Year', figsize=(20,10))
plt.suptitle('')
plt.title("Nifty 50 P/E from 2003 to 2019 yearly")
# Out:
# Text(0.5, 1.0, 'Nifty 50 P/E from 2003 to 2019 yearly')

# %%
def load_data(path, index_name):
    fs = [name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name)) and name.startswith(index_name)]
    dfs = []
    for each in fs:
        dfs.append(pd.read_csv(os.path.join(p, each)))
    df = pd.concat(dfs, ignore_index = False)
    return df

p = r"C:\Users\e1077783\Downloads"
df_100 = load_data(p, 'NIFTY100')
df_100.shape
# Out:
# (4041, 4)

# %%
df_100['Month'] = list(map(lambda x: time.strptime(x, "%d-%b-%Y").tm_mon, df_100['Date']))

# %%
df_100['Year'] = list(map(lambda x: time.strptime(x, "%d-%b-%Y").tm_year, df_100["Date"]))

# %%
df_100.boxplot(column='P/E', by='Month', figsize=(20,10))
plt.suptitle('')
plt.title("Nifty 100 P/E monthly from 2003 to 2019")
# Out:
# Text(0.5, 1.0, 'Nifty 100 P/E monthly from 2003 to 2019')

# %%
df_100.boxplot(column='P/E', by='Year', figsize=(20, 10))
plt.suptitle("")
plt.title("Nifty 100 P/E yearly from 2003 to 2019")
# Out:
# Text(0.5, 1.0, 'Nifty 100 P/E yearly from 2003 to 2019')

# %%
df_50 = df_50.set_index('Date')

# %%
df_50.head()
# Out:
#                P/E   P/B  Div Yield  Month  Year
# Date
# 01-Jan-2003  14.92  2.41       2.38      1  2003
# 02-Jan-2003  14.82  2.39       2.40      1  2003
# 03-Jan-2003  14.78  2.38       2.40      1  2003
# 06-Jan-2003  14.71  2.37       2.42      1  2003
# 07-Jan-2003  14.67  2.37       2.42      1  2003

# %%
df_100 = df_100.set_index("Date")
df_100.head()
# Out:
#                P/E   P/B  Div Yield  Month  Year
# Date
# 01-Jan-2003  14.04  2.14       2.73      1  2003
# 02-Jan-2003  14.15  2.16       2.71      1  2003
# 03-Jan-2003  14.10  2.15       2.72      1  2003
# 06-Jan-2003  14.04  2.14       2.73      1  2003
# 07-Jan-2003  14.01  2.14       2.74      1  2003

# %%
df_50[["P/E"]].plot(kind='line', figsize=(20,10))

# %%
df_100[["P/E"]].plot(kind='line', figsize=(20,10))

# %%
df_50[["P/E"]].plot(kind='box', figsize=(20,10))

# %%
df_100[["P/E"]].plot(kind='box', figsize=(20,10))
plt.yticks(np.arange(10,30, 2.5))
# Out:
# ([<matplotlib.axis.YTick at 0x1940f0d5cc0>,
#   <matplotlib.axis.YTick at 0x1940f0d5630>,
#   <matplotlib.axis.YTick at 0x1940f09d390>,
#   <matplotlib.axis.YTick at 0x1940f0fc748>,
#   <matplotlib.axis.YTick at 0x1940f0fccf8>,
#   <matplotlib.axis.YTick at 0x1940f102208>,
#   <matplotlib.axis.YTick at 0x1940f1026d8>,
#   <matplotlib.axis.YTick at 0x1940f09de10>],
#  <a list of 8 Text yticklabel objects>)

# %% [markdown]
# ## Boxplot of Nifty 50 and 100 P/E on calendar days shows that there is not much variation depending on calendar day

# %%
df_50['Day'] = list(map(lambda x : time.strptime(x, "%d-%b-%Y").tm_mday, df_50.index))

# %%
df_100['Day'] = list(map(lambda x : time.strptime(x, "%d-%b-%Y").tm_mday, df_100.index))

# %%
df_50.boxplot(column='P/E', by="Day", figsize=(25,10))

# %%
df_100.boxplot(column='P/E', by='Day', figsize=(20,10))

# %%
last_thursdays = get_last_thrusdays_of_every_month(2003, 2019)
# Out:
# 204

# %%
dates = []
for each in last_thursdays:
    dates.append(each.strftime("%d-%b-%Y"))
print(dates)
# Out:
# ['30-Jan-2003', '27-Feb-2003', '27-Mar-2003', '24-Apr-2003', '29-May-2003', '26-Jun-2003', '31-Jul-2003', '28-Aug-2003', '25-Sep-2003', '30-Oct-2003', '27-Nov-2003', '25-Dec-2003', '29-Jan-2004', '26-Feb-2004', '25-Mar-2004', '29-Apr-2004', '27-May-2004', '24-Jun-2004', '29-Jul-2004', '26-Aug-2004', '30-Sep-2004', '28-Oct-2004', '25-Nov-2004', '30-Dec-2004', '27-Jan-2005', '24-Feb-2005', '31-Mar-2005', '28-Apr-2005', '26-May-2005', '30-Jun-2005', '28-Jul-2005', '25-Aug-2005', '29-Sep-2005', '27-Oct-2005', '24-Nov-2005', '29-Dec-2005', '26-Jan-2006', '23-Feb-2006', '30-Mar-2006', '27-Apr-2006', '25-May-2006', '29-Jun-2006', '27-Jul-2006', '31-Aug-2006', '28-Sep-2006', '26-Oct-2006', '30-Nov-2006', '28-Dec-2006', '25-Jan-2007', '22-Feb-2007', '29-Mar-2007', '26-Apr-2007', '31-May-2007', '28-Jun-2007', '26-Jul-2007', '30-Aug-2007', '27-Sep-2007', '25-Oct-2007', '29-Nov-2007', '27-Dec-2007', '31-Jan-2008', '28-Feb-2008', '27-Mar-2008', '24-Apr-2008', '29-May-2008', '26-Jun-2008', '31-Jul-2008', '28-Aug-2008', '25-Sep-2008', '30-Oct-2008', '27-Nov-2008', '25-Dec-2008', '29-Jan-2009', '26-Feb-2009', '26-Mar-2009', '30-Apr-2009', '28-May-2009', '25-Jun-2009', '30-Jul-2009', '27-Aug-2009', '24-Sep-2009', '29-Oct-2009', '26-Nov-2009', '31-Dec-2009', '28-Jan-2010', '25-Feb-2010', '25-Mar-2010', '29-Apr-2010', '27-May-2010', '24-Jun-2010', '29-Jul-2010', '26-Aug-2010', '30-Sep-2010', '28-Oct-2010', '25-Nov-2010', '30-Dec-2010', '27-Jan-2011', '24-Feb-2011', '31-Mar-2011', '28-Apr-2011', '26-May-2011', '30-Jun-2011', '28-Jul-2011', '25-Aug-2011', '29-Sep-2011', '27-Oct-2011', '24-Nov-2011', '29-Dec-2011', '26-Jan-2012', '23-Feb-2012', '29-Mar-2012', '26-Apr-2012', '31-May-2012', '28-Jun-2012', '26-Jul-2012', '30-Aug-2012', '27-Sep-2012', '25-Oct-2012', '29-Nov-2012', '27-Dec-2012', '31-Jan-2013', '28-Feb-2013', '28-Mar-2013', '25-Apr-2013', '30-May-2013', '27-Jun-2013', '25-Jul-2013', '29-Aug-2013', '26-Sep-2013', '31-Oct-2013', '28-Nov-2013', '26-Dec-2013', '30-Jan-2014', '27-Feb-2014', '27-Mar-2014', '24-Apr-2014', '29-May-2014', '26-Jun-2014', '31-Jul-2014', '28-Aug-2014', '25-Sep-2014', '30-Oct-2014', '27-Nov-2014', '25-Dec-2014', '29-Jan-2015', '26-Feb-2015', '26-Mar-2015', '30-Apr-2015', '28-May-2015', '25-Jun-2015', '30-Jul-2015', '27-Aug-2015', '24-Sep-2015', '29-Oct-2015', '26-Nov-2015', '31-Dec-2015', '28-Jan-2016', '25-Feb-2016', '31-Mar-2016', '28-Apr-2016', '26-May-2016', '30-Jun-2016', '28-Jul-2016', '25-Aug-2016', '29-Sep-2016', '27-Oct-2016', '24-Nov-2016', '29-Dec-2016', '26-Jan-2017', '23-Feb-2017', '30-Mar-2017', '27-Apr-2017', '25-May-2017', '29-Jun-2017', '27-Jul-2017', '31-Aug-2017', '28-Sep-2017', '26-Oct-2017', '30-Nov-2017', '28-Dec-2017', '25-Jan-2018', '22-Feb-2018', '29-Mar-2018', '26-Apr-2018', '31-May-2018', '28-Jun-2018', '26-Jul-2018', '30-Aug-2018', '27-Sep-2018', '25-Oct-2018', '29-Nov-2018', '27-Dec-2018', '31-Jan-2019', '28-Feb-2019', '28-Mar-2019', '25-Apr-2019', '30-May-2019', '27-Jun-2019', '25-Jul-2019', '29-Aug-2019', '26-Sep-2019', '31-Oct-2019', '28-Nov-2019', '26-Dec-2019']

# %%
df_50_on_expiry = df_50.reindex().loc[dates]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
df_100_on_expiry = df_100.reindex().loc[dates]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
df_50_on_expiry.boxplot(column='P/E', by='Month', figsize=(20,10))

# %%
df_100_on_expiry.boxplot(column='P/E', by='Month', figsize=(20,10))

# %%
df_50_on_expiry.boxplot(column='P/E', by='Year', figsize=(20,10))
df_100_on_expiry.boxplot(column='P/E', by='Year', figsize=(20,10))

# %%
df_50_on_expiry.boxplot(column='P/E', by='Month', figsize=(20,10), notch=True)
df_100_on_expiry.boxplot(column='P/E', by='Month', figsize=(20,10), notch=True)

# %%
df_50.boxplot(column='P/E', by='Month', figsize=(20,10), notch=True)
df_100.boxplot(column='P/E', by='Month', figsize=(20,10), notch=True)

# %%
# %autosave 0
# Out:
# Autosave disabled
